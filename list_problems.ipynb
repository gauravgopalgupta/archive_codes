# %% [markdown]
# ## Problem 1 : Merging multiple lists

# %% [markdown]
# #### Write a code which converts (merge) multiple lists into a single lists.

# %%
l1 = [[1,3,5], [7,9,11]]

[num for sublist in l1 for num in sublist]
# Out:
# [1, 3, 5, 7, 9, 11]
